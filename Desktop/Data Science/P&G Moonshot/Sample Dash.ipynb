# %%
import pandas as pd
import plotly
import requests

# %%
url = 'https://github.com/aescay/moonshot/blob/master/Desktop/Data%20Science/P%26G%20Moonshot/Test.csv'

# %%
pd.read_csv(url, error_bad_lines=False)
# Out:
# b'Skipping line 31: expected 1 fields, saw 3\nSkipping line 73: expected 1 fields, saw 5\nSkipping line 122: expected 1 fields, saw 3\nSkipping line 132: expected 1 fields, saw 3\nSkipping line 136: expected 1 fields, saw 3\nSkipping line 141: expected 1 fields, saw 3\nSkipping line 146: expected 1 fields, saw 3\nSkipping line 150: expected 1 fields, saw 3\nSkipping line 164: expected 1 fields, saw 2\nSkipping line 180: expected 1 fields, saw 3\nSkipping line 182: expected 1 fields, saw 3\nSkipping line 7347: expected 1 fields, saw 2\nSkipping line 7348: expected 1 fields, saw 3\nSkipping line 7349: expected 1 fields, saw 3\nSkipping line 7350: expected 1 fields, saw 3\nSkipping line 7351: expected 1 fields, saw 3\nSkipping line 7352: expected 1 fields, saw 3\nSkipping line 7359: expected 1 fields, saw 3\nSkipping line 7360: expected 1 fields, saw 3\nSkipping line 7361: expected 1 fields, saw 3\nSkipping line 7362: expected 1 fields, saw 3\nSkipping line 7363: expected 1 fields, saw 
# ...

# %%
# Out:
# <Response [200]>
